# %% [markdown]
# ### Data Analysis Project using Python Modules

# %% [markdown]
# Steps involved in data anlysis project life cycle
#
# Data Collection (Collecting raw data from various data sources)
# Data Understanding
# Data Cleaning
# Data Modelling (Relation between multiple tables)
# Data Visualization (Data Analysis)

# %%
# Importing necessary python modulesimport pandas as pd
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Data Collection
# * read_csv(), which is used to read the data from csv file
# * read_excel()
# * read_json()
# * read_table()

# %%
df = pd.read_csv(r"D:/cleaned.csv")
df
# Out:
#        item_id  user_id  rating  timestamp  gender    category       brand  \
# 0            7      131       4      36692  Female  Home Audio     Philips
# 1           19      231       5      36891  Female      Camera       Canon
# 2           14      233       5      36893  Female      Camera       Kodak
# 3           14      257       5      36926  Female      Camera       Kodak
# 4           14      269       5      36952  Female      Camera       Kodak
# ...        ...      ...     ...        ...     ...         ...         ...
# 45161     7828  1157458       5      43341  Female  Headphones        Bose
# 45162     8624  1157504       5      43342  Female  Headphones        Pyle
# 45163     9513  1157527       5      43344    Male  Headphones        Mpow
# 45164     9125  1157555       3      43348  Female  Headphones      EldHus
# 45165     9478  1157632       1      43374  Female  Headphones  Etre Jeune
#
#        year  month  quantity  unitprice  amount
# ...

# %% [markdown]
# Data frame is an 2D object which is having rows and column

# %% [markdown]
# #### 2. Data Understanding
# * checking top rows - df.head()
# * checking bottom rows - df.tail()
# * checking the column names - df.columns
# * checking number of rows and columns - df.shape
# * checking null values in every column - df.isnull().sum()
# * checking duplicate rows in entire data - df.duplicated().sum()
# * checking number of unique values in every column - df.nunique()
# * checking the data types of every column - df.dtypes
# * checking entire information about dataset - df.info()
# * checking the aggregate values - df.describe()

# %%
df.head()
# Out:
#    item_id  user_id  rating  timestamp  gender    category    brand  year  \
# 0        7      131       4      36692  Female  Home Audio  Philips  2000
# 1       19      231       5      36891  Female      Camera    Canon  2000
# 2       14      233       5      36893  Female      Camera    Kodak  2001
# 3       14      257       5      36926  Female      Camera    Kodak  2001
# 4       14      269       5      36952  Female      Camera    Kodak  2001
#
#    month  quantity  unitprice  amount
# 0      6         5       6360   31800
# 1     12        10       9955   99550
# 2      1         9       7639   68751
# 3      2         7       5097   35679
# 4      3        10       6472   64720

# %%
df.tail(10)
# Out:
#        item_id  user_id  rating  timestamp  gender                 category  \
# 45156     7936  1157232       4      43337    Male    Car Electronics & GPS
# 45157     7828   301406       5      43337  Female               Headphones
# 45158     7869  1157373       4      43339  Female               Headphones
# 45159     8655  1157392       5      43340  Female  Computers & Accessories
# 45160     8863   728481       2      43340  Female               Headphones
# 45161     7828  1157458       5      43341  Female               Headphones
# 45162     8624  1157504       5      43342  Female               Headphones
# 45163     9513  1157527       5      43344    Male               Headphones
# 45164     9125  1157555       3      43348  Female               Headphones
# 45165     9478  1157632       1      43374  Female               Headphones
#
#               brand  year  month  quantity  unitprice  amount
# 45156        Garmin  2018      8         6       8298   49788
# ...

# %%
# checking the column names
df.columns
# Out:
# Index(['item_id', 'user_id', 'rating', 'timestamp', 'gender', 'category',
#        'brand', 'year', 'month', 'quantity', 'unitprice', 'amount'],
#       dtype='object')

# %%
# checking number of rows and columns
df.shape
# Out:
# (45166, 12)

# %%
# checking null values in every column 
df.isnull().sum()
# Out:
# item_id      0
# user_id      0
# rating       0
# timestamp    0
# gender       0
# category     0
# brand        0
# year         0
# month        0
# quantity     0
# unitprice    0
# amount       0
# dtype: int64

# %%
# checking duplicate rows in entire data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking number of unique values in every column
df.nunique()
# Out:
# item_id       1892
# user_id      40401
# rating           5
# timestamp     4179
# gender           2
# category        10
# brand           50
# year            19
# month           12
# quantity         6
# unitprice     5001
# amount       19611
# dtype: int64

# %%
# checking the data types of every column
df.dtypes
# Out:
# item_id       int64
# user_id       int64
# rating        int64
# timestamp     int64
# gender       object
# category     object
# brand        object
# year          int64
# month         int64
# quantity      int64
# unitprice     int64
# amount        int64
# dtype: object

# %%
# checking entire information about dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45166 entries, 0 to 45165
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_id    45166 non-null  int64
#  1   user_id    45166 non-null  int64
#  2   rating     45166 non-null  int64
#  3   timestamp  45166 non-null  int64
#  4   gender     45166 non-null  object
#  5   category   45166 non-null  object
#  6   brand      45166 non-null  object
#  7   year       45166 non-null  int64
#  8   month      45166 non-null  int64
#  9   quantity   45166 non-null  int64
#  10  unitprice  45166 non-null  int64
#  11  amount     45166 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 4.1+ MB

# %%
# checking the aggregate values
df.describe()
# Out:
#             item_id       user_id        rating     timestamp          year  \
# count  45166.000000  4.516600e+04  45166.000000  45166.000000  45166.000000
# mean    3455.669574  4.846225e+05      4.218594  42077.370743   2014.710136
# std     2485.219357  3.302487e+05      1.221118    816.969504      2.264562
# min        1.000000  2.800000e+01      1.000000  36692.000000   2000.000000
# 25%     1518.000000  1.969772e+05      4.000000  41802.000000   2014.000000
# 50%     2881.000000  4.410355e+05      5.000000  42219.000000   2015.000000
# 75%     5178.000000  7.579805e+05      5.000000  42594.000000   2016.000000
# max     9551.000000  1.157632e+06      5.000000  43374.000000   2018.000000
#
#               month      quantity     unitprice         amount
# count  45166.000000  45166.000000  45166.000000   45166.000000
# mean       6.387902      7.490878   7491.027587   56118.889032
# std        3.598405      1.707673   1441.977833   16924.053525
# ...

# %%
# Applying describe function on unitprice column
df['amount'].describe()
# Out:
# count     45166.000000
# mean      56118.889032
# std       16924.053525
# min       25000.000000
# 25%       43098.250000
# 50%       54243.000000
# 75%       67760.000000
# max      100000.000000
# Name: amount, dtype: float64

# %%
df['amount'].count()
# Out:
# np.int64(45166)

# %%
df['amount'].mean()
# Out:
# np.float64(56118.88903157242)

# %%
df['amount'].min()
# Out:
# 25000

# %%
df['amount'].max()
# Out:
# 100000

# %%
df['amount'].median()
# Out:
# 54243.0

# %%
df['amount'].std()
# Out:
# 16924.053525498868

# %%
df['amount'].var()
# Out:
# 286423587.7339507

# %% [markdown]
# #### 5. Data Visualization and Analysing the dataset

# %% [markdown]
# ### 1. What was the best year of sales

# %%
best_year = df.groupby('year')['item_id'].count()
best_year
# Out:
# year
# 2000        2
# 2001       14
# 2002       19
# 2003       46
# 2004       75
# 2005      123
# 2006      146
# 2007      335
# 2008      443
# 2009      564
# 2010      815
# 2011     1089
# 2012     1538
# 2013     3640
# 2014     7154
# 2015    11293
# 2016     9933
# 2017     5798
# 2018     2139
# Name: item_id, dtype: int64

# %%
plt.bar(best_year.index, best_year.values, color='green')
plt.plot(best_year.index, best_year.values)
plt.xlabel('Years')
plt.ylabel('Number of sales')
plt.title('Number of sales happened in each year')
# Out:
# Text(0.5, 1.0, 'Number of sales happened in each year')

# %%
plt.plot(best_year.index, year_group.values)

# %% [markdown]
# ### 2.What was the best month of sales

# %%
best_month = df.groupby('month')['item_id'].count()
best_month
# Out:
# month
# 1     4958
# 2     3952
# 3     3788
# 4     3328
# 5     3419
# 6     3448
# 7     3655
# 8     3893
# 9     3371
# 10    3316
# 11    3489
# 12    4549
# Name: item_id, dtype: int64

# %%
plt.plot(best_month.index, best_month.values, color='blue')
plt.xlabel('Months')
plt.ylabel('Number of sales')
plt.title('Number of sales happened in each month')
# Out:
# Text(0.5, 1.0, 'Number of sales happened in each month')

# %% [markdown]
# ### 3. Group by year and calculate total sales

# %%
yearly_sales = df.groupby('year')['amount'].sum()
yearly_sales
# Out:
# year
# 2000       131350
# 2001       774526
# 2002      1093002
# 2003      2703200
# 2004      4342946
# 2005      7129136
# 2006      7682219
# 2007     19014820
# 2008     25183191
# 2009     31782539
# 2010     46010449
# 2011     60980073
# 2012     86746346
# 2013    203808953
# 2014    401383841
# 2015    635759487
# 2016    558113646
# 2017    322405079
# 2018    119620939
# Name: amount, dtype: int64

# %%
plt.bar(yearly_sales.index, yearly_sales.values, color='blue')
plt.plot(yearly_sales.index, yearly_sales.values, color='red')
plt.xlabel('Years')
plt.ylabel('Total sales')
plt.title('Total sales happened in each year')
# Out:
# Text(0.5, 1.0, 'Total sales happened in each year')

# %% [markdown]
# ### 4. What brand sold the most from 2015 to 2018

# %%
filter = (df['year']>=2015) & (df['year']<=2018)
df_2015_to_2018 = df[filter]
df_2015_to_2018
# Out:
#        item_id  user_id  rating  timestamp  gender                 category  \
# 16003     5317   366625       3      42005    Male  Computers & Accessories
# 16004      259   366627       4      42005    Male               Headphones
# 16005     4517   366631       4      42005    Male               Headphones
# 16006     3539   366671       5      42005  Female   Accessories & Supplies
# 16007     5521   366713       5      42005  Female               Headphones
# ...        ...      ...     ...        ...     ...                      ...
# 45161     7828  1157458       5      43341  Female               Headphones
# 45162     8624  1157504       5      43342  Female               Headphones
# 45163     9513  1157527       5      43344    Male               Headphones
# 45164     9125  1157555       3      43348  Female               Headphones
# 45165     9478  1157632       1      43374  Female               Headphones
#
# ...

# %%
brand_group = df_2015_to_2018.groupby('brand')['amount'].sum().nlargest(10)
brand_group
# Out:
# brand
# Bose          188457327
# Logitech      144145834
# Mpow          120741465
# TaoTronics     92211364
# EldHus         90208548
# Sony           78033565
# Fujifilm       75073711
# Skullcandy     71619024
# Etre Jeune     65075467
# Sennheiser     60932194
# Name: amount, dtype: int64

# %%
plt.bar(brand_group.index, brand_group.values, color='yellow')
plt.xlabel('Brand')
plt.ylabel('Total sales')
plt.title('Top 10 Brands based on total sales')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands based on total sales')

# %% [markdown]
# ### 5. Plots for each year (2016, 2017, 2018) – brand sold the most

# %%
# filtering data for 2016, 2017 and 2018
df_2016 = df[df['year']==2016]
df_2017 = df[df['year']==2017]
df_2018 = df[df['year']==2018]

# creating brand groups for 2016, 2017 and 2018
brand_group_2016 = df_2016.groupby('brand')['amount'].sum().nlargest(5)
brand_group_2017 = df_2017.groupby('brand')['amount'].sum().nlargest(5)
brand_group_2018 = df_2018.groupby('brand')['amount'].sum().nlargest(5)

# creating subplots
fig, axs = plt.subplots(1,3, figsize=(15,4))

# plot for first subplot
axs[0].bar(brand_group_2016.index, brand_group_2016.values, color='red')
axs[0].set_title('Top 5 brands in 2016')

# plot for first subplot
axs[1].bar(brand_group_2017.index, brand_group_2017.values, color='green')
axs[1].set_title('Top 5 brands in 2017')

# plot for first subplot
axs[2].bar(brand_group_2018.index, brand_group_2018.values)
axs[2].set_title('Top 5 brands in 2018')
# Out:
# Text(0.5, 1.0, 'Top 5 brands in 2018')

# %% [markdown]
# ### 6. What product by category sold the most

# %%
top_product_category = (
    df.groupby(['category', 'item_id'])['quantity']
    .sum()
    .reset_index()
)

top_product_category = top_product_category.loc[
    top_product_category.groupby('category')['quantity'].idxmax()
]

top_product_category
# Out:
#                      category  item_id  quantity
# 10     Accessories & Supplies     1473      1444
# 409                    Camera     1605      3340
# 787     Car Electronics & GPS      283      1586
# 972   Computers & Accessories     2031     10000
# 1371               Headphones     1575     11179
# 1669               Home Audio     5054      3741
# 1798   Portable Audio & Video     7022      3397
# 1820  Security & Surveillance     3989       458
# 1857       Television & Video     2129      4497
# 1889      Wearable Technology     5402       628

# %%
filter = (df['year']>=2015) & (df['year']<=2018)
df_2015_to_2018 = df[filter]
category_group = df_2015_to_2018.groupby('category')['amount'].sum().nlargest(10)

plt.bar(category_group.index, category_group.values, color='green')
plt.xlabel('Category')
plt.ylabel('Total sales')
plt.xticks(rotation=90)
plt.title('Top 10 Categories based on total sales')
# Out:
# Text(0.5, 1.0, 'Top 10 Categories based on total sales')

# %% [markdown]
# ### 7. What product by brand sold the least between 2015 to 2018

# %%
least_product_brand = (
    df[(df.year >= 2015) & (df.year <= 2018)]
    .groupby(['brand', 'item_id'])['quantity']
    .sum()
    .idxmin()
)

least_product_brand
# Out:
# ('Apple', np.int64(1689))

# %% [markdown]
# ### 8. What product by brand sold the least between 2015 to 2018

# %%
least_product_brand = (
    df[(df.year >= 2015) & (df.year <= 2018)]
    .groupby(['brand', 'item_id'])['quantity']
    .sum()
    .idxmin()
)

least_product_brand
# Out:
# ('Apple', np.int64(1689))

# %% [markdown]
# ### 9. Distribution of ratings

# %%
rating_distribution = df['rating'].value_counts()
rating_distribution.plot(kind='bar', title="Ratings Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 10. Most rated brand between 2015 to 2018

# %%
filter = (df['year']>=2015) & (df['year']<=2018)
df_2015_to_2018 = df[filter]
brand_group = df_2015_to_2018.groupby('brand')['rating'].mean().nlargest(10)

plt.bar(brand_group.index, brand_group.values)
plt.xlabel('Brand')
plt.ylabel('Average rating')
plt.xticks(rotation=90)
plt.title('Top 10 Brand based on ratings')
# Out:
# Text(0.5, 1.0, 'Top 10 Brand based on ratings')

# %% [markdown]
# ### 11. Category percentage sales

# %%
category_group = df.groupby('category')['amount'].sum().nlargest(5)

plt.pie(category_group.values, labels=category_group.index, autopct="%.2f%%")
plt.title('Top 10 Categories with highest percentage of sales')
plt.show()

# %% [markdown]
# ### 12. Brand-wise sales percentage

# %%
brand_group = df.groupby('brand')['amount'].sum().nlargest(5)

plt.pie(brand_group.values, labels=brand_group.index, autopct="%.2f%%")
plt.title('Top 10 Brands with highest percentage of sales')
plt.show()

# %% [markdown]
# ### 13. Gender-wise customer distribution

# %%
gender_distribution = df['gender'].value_counts()
plt.pie(gender_distribution.values, labels=gender_distribution.index, autopct='%1.1f%%')
plt.title('Gender wise customer Distribution')
plt.show()

# %% [markdown]
# ### 14. Group by gender and category – total quantity sold

# %%
gender_category = df.groupby(['gender', 'category'])['quantity'].sum()

# Plot a pie chart for each gender
genders = df['gender'].unique()

for gender in genders:
    plt.pie(gender_category[gender], labels=gender_category[gender].index, autopct='%.1f%%')
    plt.title(f'{gender} - Product Preferences')
    plt.show()
